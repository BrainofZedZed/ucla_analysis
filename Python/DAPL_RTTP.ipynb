# %%
# import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read in data
df = pd.read_excel(r"C:/Users/Zach/Box/Zach_repo/Projects/DA PMA/VTA-PL PMA inhibition pilot 022521/RTPP/RTPP results_v2.xlsx")
print(df)

# create different df with just data I want to use
df_dur = df[df.columns[1:4]]
print('just duration')
print(df_dur)

# different df with just velocity
df_vel = df[df.columns[[1,5,6]]]
print('just velocity')
print(df_vel)
# Out:
#   ANIMAL ID     cond  ns:stim dur bs  ns:stim dur stim  change in dur ratio  \
# 0     DP007  control        1.660009          2.310326             0.650317
# 1     DP005     jaws        0.933613          0.277683            -0.655929
# 2     DP004     jaws        0.837110          0.766784            -0.070325
# 3     DP002     jaws        1.489627          1.491279             0.001653
#
#    ns:stim vel bs  ns:stim vel stim  chage in vel ratio
# 0        0.750000          0.615385           -0.134615
# 1        0.833333          1.333333            0.500000
# 2        1.166667          1.333333            0.166667
# 3        0.900000          0.857143           -0.042857
# just duration
#       cond  ns:stim dur bs  ns:stim dur stim
# 0  control        1.660009          2.310326
# 1     jaws        0.933613          0.277683
# 2     jaws        0.837110          0.766784
# 3     jaws        1.489627          1.491279
# just velocity
#       cond  ns:stim vel bs  ns:stim vel stim
# ...

# %%
ax = pd.plotting.parallel_coordinates(df_dur,'cond')
ax.set_xlabel('baseline vs light on')
ax.set_ylabel('NoStim : Stim duration ratio')
ax.set_title('RTPP - duration')
# Out:
# Text(0.5, 1.0, 'RTPP - duration')

# %%
ax2 = pd.plotting.parallel_coordinates(df_vel,'cond')
ax2.set_xlabel('baseline vs light on')
ax2.set_ylabel('NoStim : Stim velocity ratio')
ax2.set_title('RTPP - velocity')
# Out:
# Text(0.5, 1.0, 'RTPP - velocity')
